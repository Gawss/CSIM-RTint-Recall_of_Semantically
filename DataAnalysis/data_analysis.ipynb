# %%
# Import required libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Import the raw data
data = pd.read_csv('data.csv')
data = data.iloc[:,1:]

# Import the solutions for each pair
solutions = pd.read_csv('solutions.csv')

# %%
# Plot demographics

# Age
plt.hist(data.iloc[:,0])
plt.xlabel("Subject Age")
plt.ylabel("Frequency")
plt.title("Sample - Age Distribution")
plt.show()

# Nationality
plt.hist(data.iloc[:,1])
plt.xlabel("Subject Nationality")
plt.ylabel("Frequency")
plt.title("Sample - Nationality Distribution")
plt.show()

# Sex
plt.hist(data.iloc[:,2])
plt.xlabel("Subject Sex")
plt.ylabel("Frequency")
plt.title("Sample - Sex Distribution")
plt.show()

# %%
# Encode correct recall
for row in data.???:
    for col in data.cols

# check correct answers, if entry == correct answer:  1 else 0

# compute average confidence for each subject
# if confidence >= mean(confidenceOfSubject): 1 else 0

# Encode VisualStimulusOnShow variable
for stimulus in range(41):
    if (data.iloc[:, stimulus]%3 == 0):
        1 if data.iloc[:, stimulus] == "TRUE" else 0
        
print(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-53599210746b> in <module>
#       8 # Encode VisualStimulusOnShow variable
#       9 for stimulus in range(41):
# ---> 10     if (data.iloc[:, stimulus]%3 == 0):
#      11         1 if data.iloc[:, stimulus] == "TRUE" else 0
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1553             "The truth value of a {0} is ambiguous. "
#    1554             "Use a.empty, a.bool(), a.item(), a.any() or a.all().".format(
# -> 1555                 self.__class__.__name__
#    1556             )
#    1557         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
